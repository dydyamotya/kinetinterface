# %%
import os

#Your path to downloaded modules
path_to_modules = "C:/Users/matde/source/repos/KinetInterface/KinetInterface/"
temp_path = os.getcwd()
os.chdir(path_to_modules)
import interface
os.chdir(temp_path)
path = "D:/University/VichMetod/AVA/KINET/"
path_kin = 'D:/University/VichMetod/AVA/KINET/ftor.kin'
path_models = "D:/University/VichMetod/AVA/KINET/models/"
paths = [path, path_kin, path_models]

# %%
inter = interface.Interface(["F2"], ["F"], True, True)
inter.init_paths(paths)

# %%
inter.full_way(0.001, [1,1,3], ["F2","CH2F2","O2"],273, 125000)
# Out:
# c:\users\matde\appdata\local\programs\python\python36\lib\site-packages\pywinauto\application.py:1064: UserWarning: 32-bit application should be automated using 32-bit Python (you use 64-bit Python)
#   UserWarning)
